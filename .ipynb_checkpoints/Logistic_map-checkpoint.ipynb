# %%
using Plots

# %%
x = [0.615]
r = 3.5

function upd(x, r)
    return r*x*(1-x)
end
# Out:
# upd (generic function with 1 method)

# %%
for i in (1:50)
    push!(x, upd(x[i], r))
end

# %%
plot(x)
